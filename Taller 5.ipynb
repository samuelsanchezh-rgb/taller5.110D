# %%
print ("Hola Mundo")
# Out:
# Hola Mundo

# %%
nombre = "Samuel Sanchez"
print (nombre)
# Out:
# Samuel Sanchez

# %%
nombre = "Angie Sofia"
print (nombre)
# Out:
# Angie Sofia

# %%
print("Hola mundo, mi nombre es Samuel Esteban")
# Out:
# Hola mundo, mi nombre es Samuel Esteban

# %%
print (3+6)
# Out:
# 9

# %%
print (42-39)
# Out:
# 3

# %%
print (8*7)
# Out:
# 56

# %%
print (43586/60)
# Out:
# 726.4333333333333
